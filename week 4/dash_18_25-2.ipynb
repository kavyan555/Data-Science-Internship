# %% [markdown]
# dash framework:
#
# it is used to build interactive dashboards to make a production ready for the industry use
#
# we can easily understand the insights and patterns and take some data driven decisions

# %% [markdown]
# dash framework:
#
# we can easily create UI components where it consits of buttons,dropdowns and even sliders
#
# we connect easily with databases and apis
#
# clicking on any one vizulaization we can see all the changes in the entire dashboard

# %% [markdown]
# types of dashboard framework:
#
# I. python based:
#
# 1.streamlit:
#
# - user friendly
# - very helpful for building ai applications
# - it converts python scripts to web applications

# %% [markdown]
# 2.dash:
#
# - built on the top of plotly
# - used for building interactive analytical dashboards
# - production ready output
# - supports the callbacks(dynamic updates)

# %% [markdown]
# 3.panel:
#
# - works with bokeh,matplotlib,plotly
# - we can build customized dashboards

# %% [markdown]
# II. javascript based:
#
# 1.react
#
# 2.angular

# %% [markdown]
# III. business intelligence tools:
#
# 1.power bi
#
# 2.tableau

# %% [markdown]
# Architecture of dashboard:
#
# data source---->backend---->vizualization layer---->triggered callbacks

# %% [markdown]
# 1.data source:
#
# - sql/mongodb
#
# - apis
#
# - csv
#
# - excel
#
# - synthetic data
#
# 2.backend:
#
# - python/flask
#
# - fastapi
#
# - node js
#
# 3.vizualization layer:
#
# - plotly
#
# - matplotlib
#
# - seaborn
#
# 4.ui components:
#
# - buttons
#
# - dropdown
#
# - sliders
#
# - filters

# %% [markdown]
# key features of dash framework:
#
# - interactive charts
#
# - filter our data
#
# - production ready
#
# - dynamic dashboards
#
# - code based vizualizations

# %% [markdown]
# stock market analytics dashboard:
#
# dropdowns--->selecting some specific company
#
# date picker--->select the range
#
# line chart---->stock price
#
# bar chart---->volume
#
# kpi cards--->daily change %

# %% [markdown]
# pip install dash plotly pandas numpy

# %%
import dash
from dash import dcc,html,Input,Output
import plotly.express as px
import pandas as pd
import numpy as np

np.random.seed(42)

#create date range:

dates=pd.date_range("2024-01-01","2025-01-01")

companies=["Microsoft","Google","Apple"]

data=[]

for company in companies:
    price=1000+np.random.randint(0,200)
    for date in dates:
        price+=np.random.normal(0,8)
        volume=np.random.randint(1000,8000)

        data.append({
        "Date":date,
        "Company":company,
        "Price":round(price,2),
        "Volume":volume
        })
df=pd.DataFrame(data)


app=dash.Dash(__name__)
app.title="STOCK DASHBOARD"

app.layout=html.Div([
    html.H1("STOCK ANALYTICS DASHBOARD",style={'textAlign':'center'}),

    html.Div([
        dcc.Dropdown(
            id='company-dropdown',
            options=[{'label':c,'value':c} for c in df['Company'].unique()],
            value='Microsoft',
            clearable=False,
            style={'Width':'40%','display':'inline-block'}
        ),
        dcc.DatePickerRange(
            id='date-picker',
            start_date=df['Date'].min(),
            end_date=df['Date'].max(),
            style={'width':'50%','display':'inline-block','marginLeft':'5%'}
        )
    ]),
    html.Br(),

    html.Div(
        id='daily-change-card',
        style={
            'padding':'20px',
            'width':'25%',
            'textAlign':'center',
            'fontSize':'20px',
            'borderRadius':'10px',
            'backgroundColor':'#f4f4f4',
            'margin':'auto'
        }
    ),
    html.Br(),

    dcc.Graph(id='price-line-chart'),
    dcc.Graph(id='volume-bar-chart')
])

# Callback
@app.callback(
    Output('price-line-chart', 'figure'),
    Output('volume-bar-chart', 'figure'),
    Output('daily-change-card', 'children'),
    Input('company-dropdown', 'value'),
    Input('date-picker', 'start_date'),
    Input('date-picker', 'end_date')
)

def update_dashboard(selected_company, start_date, end_date):

    # Filter Data
    filtered = df[
        (df['Company'] == selected_company) &
        (df['Date'] >= start_date) &
        (df['Date'] <= end_date)
    ]

    # Line Chart
    price_fig = px.line(
        filtered,
        x="Date",
        y="Price",
        title=f"{selected_company} Stock Price"
    )

    # Bar Chart
    volume_fig = px.bar(
        filtered,
        x="Date",
        y="Volume",
        title=f"{selected_company} Trading Volume"
    )

    # Daily % Change
    if len(filtered) > 1:
        latest = filtered.iloc[-1]["Price"]
        previous = filtered.iloc[-2]["Price"]
        daily_change = ((latest - previous) / previous) * 100
    else:
        daily_change = 0

    kpi_text = f"Daily Change: {daily_change:.2f}%"

    return price_fig, volume_fig, kpi_text


# Run App
if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# Static dashboards:

# %% [markdown]
# 1. 📊 Sales Dashboard

# %% [markdown]
# 2. STOCK ANALYTICS DASHBOARD

# %% [markdown]
# Dynamic dashboards

# %% [markdown]
# 3. 📊 Clickable Interactive Dashboard

# %% [markdown]
# why dcc are important?
#
# what is a callback in dash?
#
# what is dash?what are the different components available in the dash?
#
# can one callback have multiple inputs and outputs?
#
# how does dash handles frontend and backend communication?
#
# how do we improve dash performance?
#
# how we can built dynamic dashboard?

# %% [markdown]
# scenerio based:
#
# how do you implement auto refresh stock updates?
#
# how do you handle large datasets?
#
# what is the difference between dash framework and bi tools?
#
# if you create any dashboard how you are going to explain that project in a minute
