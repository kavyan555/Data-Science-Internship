# %% [markdown]
# seaborn:
#
# it is a python library which is used to build interactive vizulaizations
#
# this library makes us easy to understand the statistical representation
#
# we can easily understand the patterns and relationships inside the data
#
# with the help of this vizualizations we can easily take some data driven decisions

# %% [markdown]
# seaborn has different categories while plotting the data:
#
# categorical plots
#
# distribution plots
#
# regression plots
#
# matrix plots
#
#
# relational plots
#
# multi plot grids

# %% [markdown]
# categorical plots:
#
# it is used to vizualize the data on different categories
#
# barplot()
#
# boxplot()
#
# violinplot()
#
# countplot()
#
# stripplot()
#
# factorplot()

# %% [markdown]
# distribution plots:
#
# whenever we want to see the distributions between univaraite and bivariate analysis
#
# jointplot
#
# distplot
#
# pairplot
#
# rugplot

# %% [markdown]
# regression plot:
#
# it is used to show the data columns relationships in a linear way
#
# lmplot
#
# regplot

# %% [markdown]
# matrix plot:
#
# it is used to show the data in a matrix form
#
# heatmap

# %% [markdown]
# relational plot:
#
# it is used to show the relationships between two variables
#
# relplot()
#
# scatterplot()
#
# lineplot()

# %% [markdown]
# multi plot grids:
#
# it is used to vizualize multiple instances of the same plot on different subsets of data
#
# facetgrid

# %% [markdown]
# barplot:it is used to display the aggregated values(mean,min,max) for different categories of data
#
# lineplot:it is used to display the relationship between two numeric columns in a continuous line
#
# scatterplot:it is used to show the relationship between two columns(input/output)
#
# countplot:it is used to show the count of observations in each category
#
# histogram:it is used to show the distributions of the data
#
# kde:it is used to show the kernel density estimator how the curve of the data is representating the viz
#
# boxplot:used to display the outliers inside the data
#
# violinplot:combination of boxplot and kde plot
#
# heatmap:it is used to show the correlation of the data in a matrix form
#
# pairplot:used to  show all the numeric columns(scatterplot,kde,hist)
#
# lmpoint:scatter plot with regression line

# %% [markdown]
# pip install seaborn

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(42)

# Create synthetic data
n = 300

data = pd.DataFrame({
    "Date": pd.date_range(start="2024-01-01", periods=n, freq="D"),
    "Region": np.random.choice(["North", "South", "East", "West"], n),
    "Category": np.random.choice(["Electronics", "Clothing", "Home", "Sports"], n),
    "Sales": np.random.normal(500, 120, n).round(2),
    "Profit": np.random.normal(80, 30, n).round(2),
    "Quantity": np.random.randint(1, 20, n),
    "Discount": np.random.uniform(0, 0.3, n).round(2),
    "Customer_Age": np.random.randint(18, 65, n)
})

# %%
data
# Out:
#           Date Region     Category   Sales  Profit  Quantity  Discount  \
# 0   2024-01-01   East  Electronics  505.47   78.02         4      0.05
# 1   2024-01-02   West  Electronics  421.81   43.67        18      0.26
# 2   2024-01-03  North         Home  757.27   60.44         5      0.07
# 3   2024-01-04   East     Clothing  576.07   81.42        16      0.29
# 4   2024-01-05   East     Clothing  256.98   54.19         1      0.10
# ..         ...    ...          ...     ...     ...       ...       ...
# 295 2024-10-22   West       Sports  505.77   64.31        14      0.30
# 296 2024-10-23  South  Electronics  531.17   67.39        11      0.20
# 297 2024-10-24   East         Home  391.48   71.55        18      0.17
# 298 2024-10-25  North       Sports  576.63   39.67        12      0.22
# 299 2024-10-26   West     Clothing  300.62   52.44        12      0.14
#
#      Customer_Age
# 0              25
# 1              39
# 2              61
# 3              53
# 4              22
# ..            ...
# 295            42
# 296            26
# 297            19
# 298            32
# 299            20
#
# [300 rows x 8 columns]

# %%
sns.histplot(data["Sales"],kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.boxplot(x="Category",y="Sales",data=data)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
sns.barplot(x="Region",y="Profit",data=data)
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %%
sns.scatterplot(x="Discount",y="Sales",data=data)
# Out:
# <Axes: xlabel='Discount', ylabel='Sales'>

# %%
sns.countplot(x="Region",data=data)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.jointplot(data)

# %%
sns.pairplot(data=data)

# %% [markdown]
# what is seaborn how it is different from matplotlib?
#
# how to install seaborn library?
#
# what is the difference between
# countplot() and barplot()
#
# how do you create a boxplot in seaborn?
#
# what is the use of hue parameter?
#
# what is kdeplot?
#
# what is the use of jointplot?
#
# what is pairplot() what is the importance of pairplot?
#
# what is the difference between distplot() and histplot()?
#
# how do you create heatmap?
#
# what are the different categories available in seaborn library?
#
# how do we create a histplot?
#
# how do you vizulaize the correlation matrix?

# %% [markdown]
# dashboard---multiple plots
#
# streamlit ---web application
#
# dashboard with the help of library i.e plotly

# %% [markdown]
# plotly:it is one of the library which is used to vizualize the data in more interactive way

# %% [markdown]
# pip install plotly

# %%
import plotly.express as px

# %%
d1=px.bar(data,x="Category",y="Sales",color="Region")

# %%
d1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="33a6b643-fc48-49bd-ada2-b11cc7ebbbb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33a6b643-fc48-49bd-ada2-b11cc7ebbbb4")) {                    Plotly.newPlot(                        "33a6b643-fc48-49bd-ada2-b11cc7ebbbb4",                        [{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"textposition":"auto","x":["Electronics","Clothing","Clothing","Sports","Sports","Home","Sports","Home","Clothing","Sports","Home","Sports","Sports","Sports","Electronics","Sports","Electronics","Sports","Electronics","Home","Clothing","Sports","Electronics","Sports","Sports","Clothing","Sports","Home","Home","Sports","Home","Home","Home","Clothing","Clothing","Clothing","Clothing","Clothing","Clothing","Electronics","Electronics","Home","Electronics","Sports","Sports","Clothing","Clothing","Sports","Electronics","Sports","Electronics","Clothing","Electronics","Sports","Home","Electronics","Electronics","Clothing","Clothing","Clothing","Clothing","Sports","Home","Electronics","Clothing","Electronics","Home","Sports","Sports","Clothing","Sports","Home","Home","Clothing","Home","Sports","Home"],"xaxis":"x","y":[505.47,576.07,256.98,404.9,560.6,603.89,355.96,459.86,610.14,327.7,639.58,501.23,453.76,690.32,755.96,481.79,475.03,429.28,601.95,607.95,473.88,599.05,581.83,462.77,509.1,529.24,439.17,326.23,379.7,526.89,502.94,522.0,762.78,403.0,245.13,436.91,518.05,614.05,341.57,648.54,308.67,445.99,514.44,561.73,365.04,653.32,410.18,508.1,747.29,470.12,616.59,664.24,384.21,255.29,467.67,680.28,251.91,489.31,580.36,543.99,614.62,381.71,560.49,466.99,664.02,569.19,385.34,370.21,702.46,677.59,375.53,611.14,729.13,590.65,382.69,568.47,391.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eCategory=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"textposition":"auto","x":["Electronics","Electronics","Home","Home","Electronics","Home","Clothing","Clothing","Sports","Sports","Sports","Electronics","Clothing","Home","Home","Home","Sports","Home","Clothing","Clothing","Home","Sports","Electronics","Electronics","Clothing","Electronics","Electronics","Home","Home","Clothing","Electronics","Sports","Home","Clothing","Electronics","Sports","Clothing","Electronics","Electronics","Sports","Electronics","Electronics","Electronics","Sports","Sports","Clothing","Home","Clothing","Electronics","Sports","Electronics","Sports","Home","Sports","Electronics","Home","Sports","Home","Sports","Sports","Home","Sports","Electronics","Electronics","Home","Clothing","Clothing","Home","Electronics","Sports","Clothing","Sports","Home","Electronics","Clothing","Clothing","Clothing","Electronics","Electronics","Sports","Clothing"],"xaxis":"x","y":[421.81,522.37,443.01,711.85,548.6,348.69,441.89,652.03,388.77,492.86,469.69,447.19,555.45,523.89,427.97,508.38,265.75,570.6,533.72,597.54,400.52,565.65,475.74,631.85,597.62,502.52,511.64,401.81,751.09,575.4,482.35,432.35,529.4,443.48,331.1,537.31,602.92,465.36,562.32,683.93,486.95,674.14,758.38,407.92,604.68,428.07,559.03,641.53,443.7,486.26,500.63,574.74,371.89,288.95,586.11,695.43,295.59,493.33,438.34,492.48,404.86,525.68,486.52,473.48,573.7,590.9,223.77,697.4,409.24,499.04,394.93,334.06,567.56,421.92,441.54,396.32,471.33,391.09,565.2,505.77,300.62],"yaxis":"y","type":"bar"},{ ...
